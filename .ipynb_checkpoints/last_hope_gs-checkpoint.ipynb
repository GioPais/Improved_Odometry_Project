# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dense, Dropout
from keras import backend as K
import numpy as np
import seaborn as sns

# %%
sns.set()
sns.set_context('notebook',font_scale=1.4)
pyplot.rcParams['figure.figsize']=(25,12)

# %%
gt = read_csv('pca_df.csv')

# %%
list(gt)
# Out:
# ['PC1',
#  'PC2',
#  'PC3',
#  'PC4',
#  'PC5',
#  'PC6',
#  'PC7',
#  'PC8',
#  'PC9',
#  'PC10',
#  'PC11',
#  'PC12',
#  'PC13',
#  'PC14',
#  'PC15',
#  'PC16',
#  'PC17',
#  'PC18',
#  'PC19',
#  '.pose.pose.position.x',
#  '.pose.pose.position.y',
#  '.pose.pose.position.z',
#  '.pose.pose.orientation.x',
#  '.pose.pose.orientation.y',
#  '.pose.pose.orientation.z',
#  '.pose.pose.orientation.w']

# %%
print(gt.head())
gt = gt[[".pose.pose.position.x",".pose.pose.position.y"]]
gt = gt.values
print(gt)
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -0.851072  8.044216  0.326841 -1.044230  2.307484  1.075863  3.638323
# 1 -0.564265  8.143598  0.277990 -0.437284  1.891698  0.630888  3.733934
# 2 -0.344030  8.164862  0.485255 -0.638983  1.044315  1.209261  3.248368
# 3 -0.176959  8.179082  0.546207 -0.434098  0.953136  0.805202  3.497788
# 4 -0.109958  8.211974  0.486941 -0.138914  0.705735  0.631348  3.641314
#
#         PC8       PC9      PC10            ...                 PC17      PC18  \
# 0  4.274178  2.717133 -0.704123            ...            -1.655194  1.958867
# 1  1.592049  2.517208 -0.030412            ...             0.399774  1.910119
# 2  4.415842  0.998141  0.345600            ...             1.202330  1.503087
# 3  2.762791  1.320751  0.095173            ...             0.692561  2.706914
# 4  3.152261  0.852382  0.061224            ...             0.396012  2.190524
#
#        PC19  .pose.pose.position.x  .pose.pose.position.y  \
# 0  0.460268               0.909194              -0.086818
# 1 -0.349404               0.909462              -0.087017
# 2  0.549356               0.909194              -0.086818
# 3  0.255301               0.909194              -0.086818
# 4 -0.041790               0.909194              -0.086818
#
#    .pose.pose.position.z  .pose.pose.orientation.x  .pose.pose.orientation.y  \
# 0               0.819903                  0.010896                  0.010932
# 1               0.819894                  0.011137                  0.011660
# 2               0.819903                  0.010896                  0.010932
# 3               0.819903                  0.010896                  0.010932
# 4               0.819903                  0.010896                  0.010932
#
#    .pose.pose.orientation.z  .pose.pose.orientation.w
# 0                 -0.314718                  0.949060
# 1                 -0.314720                  0.949048
# 2                 -0.314718                  0.949060
# 3                 -0.314718                  0.949060
# 4                 -0.314718                  0.949060
#
# [5 rows x 26 columns]
# [[ 0.90919352 -0.08681773]
#  [ 0.90946156 -0.0870174 ]
#  [ 0.90919352 -0.08681773]
#  ...
#  [ 1.85841024 -0.5969516 ]
#  [ 1.85841024 -0.5969516 ]
#  [ 1.85841024 -0.5969516 ]]

# %%
ft = read_csv('pca_df.csv')
#print(ft)
ft = ft.values[:,0:19]
print(ft.shape)
print(gt.shape)
# Out:
# (18126, 19)
# (18126, 2)

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# normalize features
ft_scaler = MinMaxScaler(feature_range=(-1, 1))
ft_sc = ft_scaler.fit_transform(ft)
#gt_scaler = MinMaxScaler(feature_range=(-1,1))
#gt_sc = gt_scaler.fit_transform(gt)
#specify the number of lag hours
gt_sc=gt
n_hours = 10
n_features = 19
# frame as supervised learning
reframed = series_to_supervised(ft_sc, n_hours, 1)
print(reframed.shape)
print(reframed.head())
# Out:
# (18116, 209)
#     var1(t-10)  var2(t-10)  var3(t-10)  var4(t-10)  var5(t-10)  var6(t-10)  \
# 10   -0.715661    0.912124   -0.516294   -0.909127   -0.554948    0.013421
# 11   -0.700331    0.923405   -0.518159   -0.886534   -0.576755   -0.040784
# 12   -0.688560    0.925818   -0.510249   -0.894042   -0.621199    0.029671
# 13   -0.679630    0.927432   -0.507923   -0.886416   -0.625981   -0.019550
# 14   -0.676049    0.931166   -0.510185   -0.875428   -0.638956   -0.040728
#
#     var7(t-10)  var8(t-10)  var9(t-10)  var10(t-10)    ...     var10(t)  \
# 10    0.655249    0.553081    0.373648    -0.045019    ...    -0.018136
# 11    0.673072    0.177793    0.345796    -0.021662    ...    -0.022740
# 12    0.582559    0.572903    0.134165    -0.008627    ...    -0.041608
# 13    0.629053    0.341605    0.179110    -0.017309    ...    -0.033457
# 14    0.655807    0.396101    0.113858    -0.018486    ...    -0.022294
#
#     var11(t)  var12(t)  var13(t)  var14(t)  var15(t)  var16(t)  var17(t)  \
# 10 -0.093213 -0.117487  0.032858 -0.114945  0.007821 -0.203628  0.229093
# 11 -0.206459 -0.176782 -0.106458 -0.156829 -0.040433 -0.054196  0.305606
# 12 -0.100022 -0.190172 -0.007054 -0.080169 -0.115595 -0.018248  0.114461
# 13 -0.158344 -0.177171  0.135092  0.028306  0.122936 -0.100145  0.129553
# 14 -0.275555 -0.214899  0.054090 -0.127503 -0.019077 -0.066916  0.276438
#
#     var18(t)  var19(t)
# 10 -0.030231 -0.253359
# 11  0.113269 -0.428118
# 12  0.114275 -0.429486
# 13  0.026465 -0.420714
# 14  0.090898 -0.354194
#
# [5 rows x 209 columns]

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 10000
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], gt_sc[:n_train_hours,:]
print(train_X)
print(train_y)
test_X, test_y = test[:, :n_obs], gt_sc[n_train_hours:,:]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
test_y = test_y[:-10,:]
# Out:
# [[-0.71566087  0.91212421 -0.51629433 ...  0.12552099 -0.07823277
#   -0.27253581]
#  [-0.7003313   0.92340481 -0.51815858 ...  0.22909346 -0.03023118
#   -0.25335908]
#  [-0.68855996  0.92581842 -0.51024888 ...  0.30560588  0.11326897
#   -0.42811761]
#  ...
#  [-0.7607772  -0.12804698 -0.51093121 ...  0.02868932  0.0877397
#   -0.48286006]
#  [-0.77243001 -0.12919634 -0.5096666  ... -0.15797009  0.08266238
#   -0.4530655 ]
#  [-0.77116535 -0.13449095 -0.50725277 ...  0.13853906  0.15366004
#   -0.44799775]]
# [[ 0.90919352 -0.08681773]
#  [ 0.90946156 -0.0870174 ]
#  [ 0.90919352 -0.08681773]
#  ...
#  [ 1.26979244  0.29782158]
#  [ 1.24536765  0.29915699]
#  [ 1.23623121  0.30100036]]
# (10000, 190) 10000 (10000, 2)
# (10000, 10, 19) (10000, 2) (8116, 10, 19) (8126, 2)

# %%
HUBER_DELTA = 0.5
def smoothL1(y_true, y_pred):
    x= K.abs(y_true - y_pred)
    x= K.switch(x < HUBER_DELTA, 0.5 * x ** 2, HUBER_DELTA * (x - 0.5 * HUBER_DELTA))
    return  K.sum(x)

# %%
def dice_loss():
    def dice(y_true, y_pred):
        return smoothL1(y_true, y_pred)
    return dice

# %%
def create_model():
	# create model
	model = Sequential()
	model.add(Dense(12, input_dim=8, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model


# design network
model = Sequential()
#model.add(Dense(50))
#model.add(Dense(100))
#model.add(Dense(100))
#model.add(Dropout(0.5))
model.add(LSTM(50,input_shape=(train_X.shape[1],train_X.shape[2]),return_sequences=True,))
#model.add(Dropout(0.3))# return a single vector of dimension 32
model.add(LSTM(50,return_sequences=True,))  # returns a sequence of vectors of dimension 32
model.add(LSTM(50))  # returns a sequence of vectors of dimension 32

#model.add(Dense(100))
model.add(Dense(2))
model_dice = dice_loss()
# compile model
model.compile(loss=model_dice, optimizer='adam')
#model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=400, batch_size=150, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train on 10000 samples, validate on 8116 samples
# Epoch 1/400
#  - 15s - loss: 75.2073 - val_loss: 80.8500
# Epoch 2/400
#  - 6s - loss: 69.1733 - val_loss: 83.3084
# Epoch 3/400
#  - 7s - loss: 67.2237 - val_loss: 85.3245
# Epoch 4/400
#  - 7s - loss: 66.2653 - val_loss: 86.0096
# Epoch 5/400
#  - 7s - loss: 66.5055 - val_loss: 86.6631
# Epoch 6/400
#  - 7s - loss: 66.2136 - val_loss: 86.9512
# Epoch 7/400
#  - 8s - loss: 66.3269 - val_loss: 89.1535
# Epoch 8/400
#  - 8s - loss: 65.5633 - val_loss: 89.8331
# Epoch 9/400
#  - 8s - loss: 65.5277 - val_loss: 91.2252
# Epoch 10/400
#  - 8s - loss: 65.0619 - val_loss: 92.1256
# Epoch 11/400
#  - 8s - loss: 64.6297 - val_loss: 93.0869
# Epoch 12/400
#  - 8s - loss: 64.0748 - val_loss: 92.9289
# Epoch 13/400
#  - 8s - loss: 63.4084 - val_loss: 91.9833
# Epoch 14/400
#  - 7s - loss: 62.9669 - val_loss: 90.9874
# Epoch 15/400
#  - 7s - loss: 62.6125 - val_loss: 89.9916
# Epoch 16/400
#  - 8s - loss: 62.2768 - val_loss: 89.0231
# Epoch 17/400
#  - 8s - loss: 61.9463 - val_loss: 88.1870
# Epoch 18/400
#  - 8s - loss: 61.5968 - val_loss: 87.5540
# Epoch 19/400
#  - 8s - loss: 61.2142 - val_loss: 87.1794
# Epoch 20/400
#  - 7s - loss: 60.7966 - val_loss: 87.0453
# Epoch 21/400
#  - 8s - loss: 60.3561 - val_loss: 86.8789
# Epoch 22/400
#  - 8s - loss: 59.8913 - val_loss: 86.4087
# Epoch 23/400
#  - 7s - loss: 59.4116 - val_loss: 85.7415
# Epoch 24/400
#  - 6s - loss: 58.9387 - val_loss: 85.0076
# Epoch 25/400
#  - 6s - loss: 58.4916 - val_loss: 84.2755
# Epoch 26/400
#  - 7s - loss: 58.0774 - val_loss: 83.6387
# Epoch 27/400
#  - 6s - loss: 57.6994 - val_loss: 82.9907
# Epoch 28/400
#  - 6s - loss: 57.3341 - val_loss: 82.4246
# Epoch 29/400
#  - 6s - loss: 56.9694 - val_loss: 81.9626
# Epoch 30/400
#  - 7s - loss: 56.5707 - val_loss: 81.6755
# Epoch 31/400
#  - 6s - loss: 56.1323 - val_loss: 81.4709
# Epoch 32/400
#  - 6s - loss: 55.6633 - val_loss: 81.4275
# Epoch 33/400
#  - 6s - loss: 55.1690 - val_loss: 81.4945
# Epoch 34/400
#  - 6s - loss: 54.6707 - val_loss: 81.6373
# Epoch 35/400
#  - 6s - loss: 54.1722 - val_loss: 81.8138
# Epoch 36/400
#  - 6s - loss: 53.6810 - val_loss: 81.9380
# Epoch 37/400
#  - 6s - loss: 53.2397 - val_loss: 81.8280
# Epoch 38/400
#  - 6s - loss: 52.9168 - val_loss: 81.4052
# Epoch 39/400
#  - 6s - loss: 52.6897 - val_loss: 80.7303
# Epoch 40/400
#  - 6s - loss: 52.4229 - val_loss: 80.0779
# Epoch 41/400
#  - 6s - loss: 51.9959 - val_loss: 79.9071
# Epoch 42/400
#  - 6s - loss: 51.4503 - val_loss: 80.5339
# Epoch 43/400
#  - 7s - loss: 50.9836 - val_loss: 81.4924
# Epoch 44/400
#  - 7s - loss: 50.5973 - val_loss: 82.4326
# Epoch 45/400
#  - 6s - loss: 50.1839 - val_loss: 83.4197
# Epoch 46/400
#  - 6s - loss: 49.6517 - val_loss: 84.2180
# Epoch 47/400
#  - 6s - loss: 49.2266 - val_loss: 84.6777
# Epoch 48/400
#  - 9s - loss: 48.8288 - val_loss: 85.0703
# Epoch 49/400
#  - 9s - loss: 48.3263 - val_loss: 85.1504
# Epoch 50/400
#  - 6s - loss: 47.7440 - val_loss: 84.7093
# Epoch 51/400
#  - 7s - loss: 47.2332 - val_loss: 84.4758
# Epoch 52/400
#  - 6s - loss: 46.6936 - val_loss: 84.1960
# Epoch 53/400
#  - 6s - loss: 46.5842 - val_loss: 82.4027
# Epoch 54/400
#  - 6s - loss: 46.0838 - val_loss: 85.4695
# Epoch 55/400
#  - 6s - loss: 46.5840 - val_loss: 82.5756
# Epoch 56/400
#  - 6s - loss: 45.4248 - val_loss: 89.0337
# Epoch 57/400
#  - 6s - loss: 45.1455 - val_loss: 81.6691
# Epoch 58/400
#  - 6s - loss: 44.4188 - val_loss: 86.4776
# Epoch 59/400
#  - 7s - loss: 45.4546 - val_loss: 76.4255
# Epoch 60/400
#  - 7s - loss: 45.3412 - val_loss: 95.8729
# Epoch 61/400
#  - 7s - loss: 43.6947 - val_loss: 86.2435
# Epoch 62/400
#  - 6s - loss: 43.3018 - val_loss: 87.9094
# Epoch 63/400
#  - 6s - loss: 44.1952 - val_loss: 81.6395
# Epoch 64/400
#  - 6s - loss: 41.9481 - val_loss: 83.8214
# Epoch 65/400
#  - 6s - loss: 43.1214 - val_loss: 91.2057
# Epoch 66/400
#  - 6s - loss: 42.1079 - val_loss: 101.2891
# Epoch 67/400
#  - 7s - loss: 40.7397 - val_loss: 94.3491
# Epoch 68/400
#  - 7s - loss: 42.9400 - val_loss: 105.1975
# Epoch 69/400
#  - 7s - loss: 41.0175 - val_loss: 84.9233
# Epoch 70/400
#  - 7s - loss: 42.7399 - val_loss: 89.6014
# Epoch 71/400
#  - 7s - loss: 41.4163 - val_loss: 93.6277
# Epoch 72/400
#  - 7s - loss: 40.3770 - val_loss: 95.8959
# Epoch 73/400
#  - 7s - loss: 38.7059 - val_loss: 98.9641
# Epoch 74/400
#  - 7s - loss: 38.6292 - val_loss: 97.1562
# Epoch 75/400
#  - 7s - loss: 39.1794 - val_loss: 93.4167
# Epoch 76/400
#  - 8s - loss: 38.7192 - val_loss: 105.8062
# Epoch 77/400
#  - 7s - loss: 37.6938 - val_loss: 87.0509
# Epoch 78/400
#  - 6s - loss: 38.5711 - val_loss: 105.3836
# Epoch 79/400
#  - 6s - loss: 37.3954 - val_loss: 88.4230
# Epoch 80/400
#  - 7s - loss: 37.7747 - val_loss: 95.8102
# Epoch 81/400
#  - 6s - loss: 37.3191 - val_loss: 88.1644
# Epoch 82/400
#  - 6s - loss: 34.8202 - val_loss: 91.5178
# Epoch 83/400
#  - 5s - loss: 34.0742 - val_loss: 89.2792
# Epoch 84/400
#  - 5s - loss: 35.2057 - val_loss: 97.3229
# Epoch 85/400
#  - 6s - loss: 34.8425 - val_loss: 89.8366
# Epoch 86/400
#  - 5s - loss: 35.9522 - val_loss: 93.6740
# Epoch 87/400
#  - 6s - loss: 33.7099 - val_loss: 94.9773
# Epoch 88/400
#  - 6s - loss: 32.4781 - val_loss: 106.3620
# Epoch 89/400
#  - 6s - loss: 33.0199 - val_loss: 93.5426
# Epoch 90/400
#  - 6s - loss: 32.6850 - val_loss: 104.7484
# Epoch 91/400
#  - 6s - loss: 31.5065 - val_loss: 94.2027
# Epoch 92/400
#  - 6s - loss: 31.5970 - val_loss: 103.8534
# Epoch 93/400
#  - 7s - loss: 31.4559 - val_loss: 92.8689
# Epoch 94/400
#  - 6s - loss: 31.8083 - val_loss: 96.7177
# Epoch 95/400
#  - 5s - loss: 30.7539 - val_loss: 99.4773
# Epoch 96/400
#  - 6s - loss: 30.4332 - val_loss: 93.7312
# Epoch 97/400
#  - 6s - loss: 29.9686 - val_loss: 104.7478
# Epoch 98/400
#  - 6s - loss: 29.2396 - val_loss: 91.1776
# Epoch 99/400
#  - 6s - loss: 28.3509 - val_loss: 110.2996
# Epoch 100/400
#  - 6s - loss: 29.0836 - val_loss: 90.8046
# Epoch 101/400
#  - 7s - loss: 28.7787 - val_loss: 96.2063
# Epoch 102/400
#  - 6s - loss: 31.1083 - val_loss: 86.6497
# Epoch 103/400
#  - 7s - loss: 34.7856 - val_loss: 100.2467
# Epoch 104/400
#  - 9s - loss: 29.2380 - val_loss: 96.4462
# Epoch 105/400
#  - 8s - loss: 28.5616 - val_loss: 90.6147
# Epoch 106/400
#  - 6s - loss: 27.8008 - val_loss: 96.1030
# Epoch 107/400
#  - 6s - loss: 25.8602 - val_loss: 101.7938
# Epoch 108/400
#  - 6s - loss: 26.1618 - val_loss: 94.9676
# Epoch 109/400
#  - 6s - loss: 24.9015 - val_loss: 99.5063
# Epoch 110/400
#  - 6s - loss: 24.9821 - val_loss: 97.1145
# Epoch 111/400
#  - 6s - loss: 23.2188 - val_loss: 88.6811
# Epoch 112/400
#  - 6s - loss: 23.0154 - val_loss: 89.7699
# Epoch 113/400
#  - 6s - loss: 22.3358 - val_loss: 93.9400
# Epoch 114/400
#  - 6s - loss: 23.0413 - val_loss: 93.5628
# Epoch 115/400
#  - 6s - loss: 22.0955 - val_loss: 93.8537
# Epoch 116/400
#  - 7s - loss: 23.2716 - val_loss: 94.9337
# Epoch 117/400
#  - 6s - loss: 23.7798 - val_loss: 89.5644
# Epoch 118/400
#  - 6s - loss: 22.0244 - val_loss: 89.0159
# Epoch 119/400
#  - 6s - loss: 20.6946 - val_loss: 93.0037
# Epoch 120/400
#  - 7s - loss: 19.7727 - val_loss: 92.2305
# Epoch 121/400
#  - 7s - loss: 19.8800 - val_loss: 95.7743
# Epoch 122/400
#  - 7s - loss: 20.4473 - val_loss: 91.5719
# Epoch 123/400
#  - 6s - loss: 20.7835 - val_loss: 89.9404
# Epoch 124/400
#  - 7s - loss: 21.3610 - val_loss: 94.3824
# Epoch 125/400
#  - 7s - loss: 20.1346 - val_loss: 91.4666
# Epoch 126/400
#  - 8s - loss: 21.4372 - val_loss: 87.3336
# Epoch 127/400
#  - 7s - loss: 22.5708 - val_loss: 88.7107
# Epoch 128/400
#  - 8s - loss: 25.3363 - val_loss: 82.5036
# Epoch 129/400
#  - 7s - loss: 24.9792 - val_loss: 116.9789
# Epoch 130/400
#  - 7s - loss: 26.7846 - val_loss: 91.1802
# Epoch 131/400
#  - 7s - loss: 21.8825 - val_loss: 91.5609
# Epoch 132/400
#  - 8s - loss: 20.8350 - val_loss: 90.7520
# Epoch 133/400
#  - 8s - loss: 19.0316 - val_loss: 93.7147
# Epoch 134/400
#  - 7s - loss: 19.2122 - val_loss: 88.7558
# Epoch 135/400
#  - 6s - loss: 17.7391 - val_loss: 89.7573
# Epoch 136/400
#  - 6s - loss: 18.9993 - val_loss: 91.8210
# Epoch 137/400
#  - 6s - loss: 18.8130 - val_loss: 89.8702
# Epoch 138/400
#  - 6s - loss: 18.0213 - val_loss: 90.2159
# Epoch 139/400
#  - 6s - loss: 18.4825 - val_loss: 90.5742
# Epoch 140/400
#  - 7s - loss: 17.2995 - val_loss: 88.5118
# Epoch 141/400
#  - 6s - loss: 17.3692 - val_loss: 88.5236
# Epoch 142/400
#  - 6s - loss: 15.0015 - val_loss: 89.7099
# Epoch 143/400
#  - 6s - loss: 16.2024 - val_loss: 91.6994
# Epoch 144/400
#  - 6s - loss: 16.8109 - val_loss: 92.9374
# Epoch 145/400
#  - 6s - loss: 15.2967 - val_loss: 86.1014
# Epoch 146/400
#  - 6s - loss: 16.5724 - val_loss: 97.9522
# Epoch 147/400
#  - 8s - loss: 16.9361 - val_loss: 92.5437
# Epoch 148/400
#  - 8s - loss: 16.9704 - val_loss: 93.3108
# Epoch 149/400
#  - 7s - loss: 14.8362 - val_loss: 91.7637
# Epoch 150/400
#  - 7s - loss: 14.7597 - val_loss: 91.3802
# Epoch 151/400
#  - 7s - loss: 15.6856 - val_loss: 94.1018
# Epoch 152/400
#  - 8s - loss: 15.5855 - val_loss: 95.5603
# Epoch 153/400
#  - 8s - loss: 17.3714 - val_loss: 89.9052
# Epoch 154/400
#  - 8s - loss: 16.0609 - val_loss: 92.6093
# Epoch 155/400
#  - 7s - loss: 16.2284 - val_loss: 85.0436
# Epoch 156/400
#  - 7s - loss: 17.3741 - val_loss: 95.3666
# Epoch 157/400
#  - 7s - loss: 15.5187 - val_loss: 86.4347
# Epoch 158/400
#  - 8s - loss: 17.1876 - val_loss: 90.1931
# Epoch 159/400
#  - 8s - loss: 16.4835 - val_loss: 91.1370
# Epoch 160/400
#  - 7s - loss: 15.2015 - val_loss: 91.1350
# Epoch 161/400
#  - 8s - loss: 12.9849 - val_loss: 90.4454
# Epoch 162/400
#  - 7s - loss: 12.6556 - val_loss: 87.9502
# Epoch 163/400
#  - 8s - loss: 13.2826 - val_loss: 90.5588
# Epoch 164/400
#  - 7s - loss: 13.6220 - val_loss: 97.7734
# Epoch 165/400
#  - 7s - loss: 12.6311 - val_loss: 90.5560
# Epoch 166/400
#  - 7s - loss: 13.9771 - val_loss: 97.7348
# Epoch 167/400
#  - 6s - loss: 17.4185 - val_loss: 89.0417
# Epoch 168/400
#  - 6s - loss: 15.3935 - val_loss: 92.0519
# Epoch 169/400
#  - 7s - loss: 13.7556 - val_loss: 87.0585
# Epoch 170/400
#  - 7s - loss: 14.8580 - val_loss: 92.9477
# Epoch 171/400
#  - 7s - loss: 12.9626 - val_loss: 91.2817
# Epoch 172/400
#  - 7s - loss: 11.3439 - val_loss: 90.8036
# Epoch 173/400
#  - 7s - loss: 11.0832 - val_loss: 87.0194
# Epoch 174/400
#  - 6s - loss: 11.3568 - val_loss: 86.7676
# Epoch 175/400
#  - 7s - loss: 11.2036 - val_loss: 94.1362
# Epoch 176/400
#  - 7s - loss: 13.6326 - val_loss: 92.9650
# Epoch 177/400
#  - 7s - loss: 12.5419 - val_loss: 91.4847
# Epoch 178/400
#  - 7s - loss: 12.4326 - val_loss: 89.5779
# Epoch 179/400
#  - 6s - loss: 13.4102 - val_loss: 91.8836
# Epoch 180/400
#  - 7s - loss: 13.8168 - val_loss: 88.9873
# Epoch 181/400
#  - 6s - loss: 17.9103 - val_loss: 92.6093
# Epoch 182/400
#  - 6s - loss: 13.9811 - val_loss: 91.5319
# Epoch 183/400
#  - 7s - loss: 11.2033 - val_loss: 89.3120
# Epoch 184/400
#  - 7s - loss: 12.0106 - val_loss: 90.8947
# Epoch 185/400
#  - 7s - loss: 10.4818 - val_loss: 91.9368
# Epoch 186/400
#  - 6s - loss: 11.8247 - val_loss: 89.3005
# Epoch 187/400
#  - 7s - loss: 11.0794 - val_loss: 89.1953
# Epoch 188/400
#  - 7s - loss: 9.6006 - val_loss: 91.2033
# Epoch 189/400
#  - 7s - loss: 8.9644 - val_loss: 90.2586
# Epoch 190/400
#  - 6s - loss: 8.2852 - val_loss: 91.5758
# Epoch 191/400
#  - 6s - loss: 8.3927 - val_loss: 87.8410
# Epoch 192/400
#  - 6s - loss: 8.4749 - val_loss: 90.3855
# Epoch 193/400
#  - 6s - loss: 8.6815 - val_loss: 93.0664
# Epoch 194/400
#  - 6s - loss: 9.3268 - val_loss: 88.6444
# Epoch 195/400
#  - 6s - loss: 10.5585 - val_loss: 90.2015
# Epoch 196/400
#  - 6s - loss: 9.5226 - val_loss: 88.8213
# Epoch 197/400
#  - 7s - loss: 9.7762 - val_loss: 91.0938
# Epoch 198/400
#  - 7s - loss: 9.8036 - val_loss: 92.2447
# Epoch 199/400
#  - 8s - loss: 8.4847 - val_loss: 91.3684
# Epoch 200/400
#  - 8s - loss: 10.3389 - val_loss: 91.1077
# Epoch 201/400
#  - 8s - loss: 11.5172 - val_loss: 94.2234
# Epoch 202/400
#  - 7s - loss: 10.5081 - val_loss: 90.8150
# Epoch 203/400
#  - 7s - loss: 11.9732 - val_loss: 90.5508
# Epoch 204/400
#  - 7s - loss: 9.9049 - val_loss: 88.1009
# Epoch 205/400
#  - 8s - loss: 13.1790 - val_loss: 93.6347
# Epoch 206/400
#  - 8s - loss: 13.2355 - val_loss: 93.0948
# Epoch 207/400
#  - 7s - loss: 11.9410 - val_loss: 86.9616
# Epoch 208/400
#  - 7s - loss: 13.6296 - val_loss: 95.5294
# Epoch 209/400
#  - 7s - loss: 13.3639 - val_loss: 89.0484
# Epoch 210/400
#  - 7s - loss: 9.6093 - val_loss: 88.1991
# Epoch 211/400
#  - 8s - loss: 8.2583 - val_loss: 91.3370
# Epoch 212/400
#  - 8s - loss: 7.8953 - val_loss: 89.9874
# Epoch 213/400
#  - 7s - loss: 6.4912 - val_loss: 95.6506
# Epoch 214/400
#  - 8s - loss: 6.1500 - val_loss: 90.8369
# Epoch 215/400
#  - 8s - loss: 6.4530 - val_loss: 91.7015
# Epoch 216/400
#  - 8s - loss: 6.7053 - val_loss: 89.7383
# Epoch 217/400
#  - 7s - loss: 6.5555 - val_loss: 93.1589
# Epoch 218/400
#  - 8s - loss: 6.9247 - val_loss: 89.3509
# Epoch 219/400
#  - 8s - loss: 6.4406 - val_loss: 93.3663
# Epoch 220/400
#  - 7s - loss: 6.9573 - val_loss: 91.6293
# Epoch 221/400
#  - 7s - loss: 6.4449 - val_loss: 90.3342
# Epoch 222/400
#  - 7s - loss: 6.4522 - val_loss: 97.1294
# Epoch 223/400
#  - 7s - loss: 7.2312 - val_loss: 91.2216
# Epoch 224/400
#  - 7s - loss: 8.5293 - val_loss: 92.0340
# Epoch 225/400
#  - 7s - loss: 9.4001 - val_loss: 92.5417
# Epoch 226/400
#  - 7s - loss: 6.6499 - val_loss: 91.5708
# Epoch 227/400
#  - 7s - loss: 6.4050 - val_loss: 93.0203
# Epoch 228/400
#  - 6s - loss: 5.9158 - val_loss: 87.8843
# Epoch 229/400
#  - 7s - loss: 6.3131 - val_loss: 90.8312
# Epoch 230/400
#  - 6s - loss: 7.5201 - val_loss: 97.9838
# Epoch 231/400
#  - 7s - loss: 7.1189 - val_loss: 91.3122
# Epoch 232/400
#  - 7s - loss: 6.1845 - val_loss: 91.1245
# Epoch 233/400
#  - 7s - loss: 6.9805 - val_loss: 87.6434
# Epoch 234/400
#  - 8s - loss: 7.2901 - val_loss: 91.0966
# Epoch 235/400
#  - 8s - loss: 7.3333 - val_loss: 91.0676
# Epoch 236/400
#  - 8s - loss: 8.6760 - val_loss: 99.3661
# Epoch 237/400
#  - 7s - loss: 10.4222 - val_loss: 88.7822
# Epoch 238/400
#  - 7s - loss: 15.0180 - val_loss: 90.6621
# Epoch 239/400
#  - 7s - loss: 18.6931 - val_loss: 85.2786
# Epoch 240/400
#  - 7s - loss: 18.1892 - val_loss: 97.7093
# Epoch 241/400
#  - 8s - loss: 15.3270 - val_loss: 84.2263
# Epoch 242/400
#  - 7s - loss: 16.6430 - val_loss: 92.3666
# Epoch 243/400
#  - 7s - loss: 10.3374 - val_loss: 84.2233
# Epoch 244/400
#  - 8s - loss: 7.5646 - val_loss: 90.5431
# Epoch 245/400
#  - 7s - loss: 7.4010 - val_loss: 91.7514
# Epoch 246/400
#  - 7s - loss: 6.1607 - val_loss: 90.2361
# Epoch 247/400
#  - 6s - loss: 5.3666 - val_loss: 92.4617
# Epoch 248/400
#  - 6s - loss: 5.3022 - val_loss: 93.6445
# Epoch 249/400
#  - 6s - loss: 4.8757 - val_loss: 92.1168
# Epoch 250/400
#  - 6s - loss: 4.4079 - val_loss: 92.9452
# Epoch 251/400
#  - 6s - loss: 4.0439 - val_loss: 91.5024
# Epoch 252/400
#  - 6s - loss: 4.1645 - val_loss: 91.5247
# Epoch 253/400
#  - 7s - loss: 3.7616 - val_loss: 91.4264
# Epoch 254/400
#  - 6s - loss: 4.4374 - val_loss: 92.8804
# Epoch 255/400
#  - 6s - loss: 4.7898 - val_loss: 90.8122
# Epoch 256/400
#  - 7s - loss: 4.1835 - val_loss: 93.6518
# Epoch 257/400
#  - 6s - loss: 3.7547 - val_loss: 90.2661
# Epoch 258/400
#  - 7s - loss: 3.4581 - val_loss: 94.3781
# Epoch 259/400
#  - 7s - loss: 3.2165 - val_loss: 91.9094
# Epoch 260/400
#  - 6s - loss: 3.2040 - val_loss: 88.9098
# Epoch 261/400
#  - 6s - loss: 3.3002 - val_loss: 95.2636
# Epoch 262/400
#  - 6s - loss: 3.9129 - val_loss: 89.3264
# Epoch 263/400
#  - 6s - loss: 4.5943 - val_loss: 94.9599
# Epoch 264/400
#  - 6s - loss: 4.2611 - val_loss: 90.0006
# Epoch 265/400
#  - 6s - loss: 4.2668 - val_loss: 92.1079
# Epoch 266/400
#  - 6s - loss: 5.1248 - val_loss: 88.6648
# Epoch 267/400
#  - 7s - loss: 5.6138 - val_loss: 97.6099
# Epoch 268/400
#  - 6s - loss: 5.0125 - val_loss: 89.3459
# Epoch 269/400
#  - 6s - loss: 6.0009 - val_loss: 92.6568
# Epoch 270/400
#  - 7s - loss: 8.4120 - val_loss: 90.4529
# Epoch 271/400
#  - 6s - loss: 8.2893 - val_loss: 96.2925
# Epoch 272/400
#  - 6s - loss: 6.2004 - val_loss: 88.0773
# Epoch 273/400
#  - 6s - loss: 6.4640 - val_loss: 89.6207
# Epoch 274/400
#  - 7s - loss: 5.7934 - val_loss: 90.8292
# Epoch 275/400
#  - 6s - loss: 5.3603 - val_loss: 88.9193
# Epoch 276/400
#  - 6s - loss: 5.4294 - val_loss: 96.2137
# Epoch 277/400
#  - 6s - loss: 5.5724 - val_loss: 85.6631
# Epoch 278/400
#  - 6s - loss: 5.9351 - val_loss: 88.8351
# Epoch 279/400
#  - 6s - loss: 6.3287 - val_loss: 85.5086
# Epoch 280/400
#  - 6s - loss: 8.5000 - val_loss: 89.3930
# Epoch 281/400
#  - 6s - loss: 12.0070 - val_loss: 79.7686
# Epoch 282/400
#  - 6s - loss: 11.8425 - val_loss: 91.0758
# Epoch 283/400
#  - 6s - loss: 11.2047 - val_loss: 90.7174
# Epoch 284/400
#  - 6s - loss: 8.4893 - val_loss: 99.8121
# Epoch 285/400
#  - 6s - loss: 8.5415 - val_loss: 91.1673
# Epoch 286/400
#  - 6s - loss: 7.3857 - val_loss: 93.0789
# Epoch 287/400
#  - 6s - loss: 6.8893 - val_loss: 94.7957
# Epoch 288/400
#  - 6s - loss: 6.0584 - val_loss: 91.5752
# Epoch 289/400
#  - 6s - loss: 6.3514 - val_loss: 90.7263
# Epoch 290/400
#  - 6s - loss: 4.7212 - val_loss: 90.4342
# Epoch 291/400
#  - 6s - loss: 4.7742 - val_loss: 90.6116
# Epoch 292/400
#  - 7s - loss: 4.0815 - val_loss: 90.2473
# Epoch 293/400
#  - 7s - loss: 3.7849 - val_loss: 93.0938
# Epoch 294/400
#  - 6s - loss: 2.9279 - val_loss: 90.0487
# Epoch 295/400
#  - 7s - loss: 2.8044 - val_loss: 90.7110
# Epoch 296/400
#  - 6s - loss: 2.7480 - val_loss: 90.3855
# Epoch 297/400
#  - 7s - loss: 2.7789 - val_loss: 91.6335
# Epoch 298/400
#  - 8s - loss: 2.5907 - val_loss: 91.6809
# Epoch 299/400
#  - 8s - loss: 2.7477 - val_loss: 89.8673
# Epoch 300/400
#  - 7s - loss: 2.3762 - val_loss: 91.4996
# Epoch 301/400
#  - 6s - loss: 2.1499 - val_loss: 89.7679
# Epoch 302/400
#  - 6s - loss: 2.2158 - val_loss: 92.8239
# Epoch 303/400
#  - 6s - loss: 2.1754 - val_loss: 87.3714
# Epoch 304/400
#  - 7s - loss: 2.0926 - val_loss: 90.6429
# Epoch 305/400
#  - 7s - loss: 2.4954 - val_loss: 92.0208
# Epoch 306/400
#  - 8s - loss: 2.5344 - val_loss: 90.2333
# Epoch 307/400
#  - 6s - loss: 2.5983 - val_loss: 85.3678
# Epoch 308/400
#  - 6s - loss: 3.4044 - val_loss: 96.5576
# Epoch 309/400
#  - 6s - loss: 3.1906 - val_loss: 93.9780
# Epoch 310/400
#  - 6s - loss: 4.0205 - val_loss: 83.8739
# Epoch 311/400
#  - 6s - loss: 5.5084 - val_loss: 87.5267
# Epoch 312/400
#  - 6s - loss: 5.7783 - val_loss: 88.9087
# Epoch 313/400
#  - 6s - loss: 5.8455 - val_loss: 96.4843
# Epoch 314/400
#  - 7s - loss: 4.9149 - val_loss: 85.2072
# Epoch 315/400
#  - 6s - loss: 8.1086 - val_loss: 85.1243
# Epoch 316/400
#  - 6s - loss: 6.3504 - val_loss: 93.7061
# Epoch 317/400
#  - 6s - loss: 5.1392 - val_loss: 85.4261
# Epoch 318/400
#  - 6s - loss: 4.0448 - val_loss: 93.6041
# Epoch 319/400
#  - 7s - loss: 4.1982 - val_loss: 93.6310
# Epoch 320/400
#  - 7s - loss: 3.8843 - val_loss: 88.3636
# Epoch 321/400
#  - 7s - loss: 3.3538 - val_loss: 85.5155
# Epoch 322/400
#  - 8s - loss: 3.8998 - val_loss: 91.1456
# Epoch 323/400
#  - 8s - loss: 3.8511 - val_loss: 93.7068
# Epoch 324/400
#  - 8s - loss: 4.0018 - val_loss: 92.5011
# Epoch 325/400
#  - 8s - loss: 3.2324 - val_loss: 91.0214
# Epoch 326/400
#  - 7s - loss: 3.2978 - val_loss: 87.1546
# Epoch 327/400
#  - 7s - loss: 3.3385 - val_loss: 88.0632
# Epoch 328/400
#  - 7s - loss: 2.9131 - val_loss: 94.0790
# Epoch 329/400
#  - 7s - loss: 2.7198 - val_loss: 89.2194
# Epoch 330/400
#  - 8s - loss: 3.8195 - val_loss: 87.6147
# Epoch 331/400
#  - 8s - loss: 3.8897 - val_loss: 88.6497
# Epoch 332/400
#  - 7s - loss: 4.6174 - val_loss: 88.9767
# Epoch 333/400
#  - 7s - loss: 5.3312 - val_loss: 89.2203
# Epoch 334/400
#  - 7s - loss: 7.4886 - val_loss: 90.0687
# Epoch 335/400
#  - 7s - loss: 7.6647 - val_loss: 85.3870
# Epoch 336/400
#  - 7s - loss: 5.6244 - val_loss: 85.0842
# Epoch 337/400
#  - 7s - loss: 5.7964 - val_loss: 91.6163
# Epoch 338/400
#  - 6s - loss: 3.9599 - val_loss: 90.8373
# Epoch 339/400
#  - 6s - loss: 3.2360 - val_loss: 89.8138
# Epoch 340/400
#  - 8s - loss: 3.0158 - val_loss: 90.1808
# Epoch 341/400
#  - 7s - loss: 2.5063 - val_loss: 90.1303
# Epoch 342/400
#  - 6s - loss: 2.1753 - val_loss: 91.3924
# Epoch 343/400
#  - 6s - loss: 2.7761 - val_loss: 87.8280
# Epoch 344/400
#  - 5s - loss: 3.2710 - val_loss: 89.0536
# Epoch 345/400
#  - 6s - loss: 4.0625 - val_loss: 94.3398
# Epoch 346/400
#  - 6s - loss: 4.5689 - val_loss: 92.1386
# Epoch 347/400
#  - 5s - loss: 5.6469 - val_loss: 89.3792
# Epoch 348/400
#  - 5s - loss: 4.1909 - val_loss: 90.1414
# Epoch 349/400
#  - 5s - loss: 4.4128 - val_loss: 93.2074
# Epoch 350/400
#  - 6s - loss: 3.7775 - val_loss: 87.0105
# Epoch 351/400
#  - 7s - loss: 3.1547 - val_loss: 87.9696
# Epoch 352/400
#  - 6s - loss: 3.2941 - val_loss: 89.6428
# Epoch 353/400
#  - 5s - loss: 3.2571 - val_loss: 92.9764
# Epoch 354/400
#  - 6s - loss: 3.3962 - val_loss: 94.2206
# Epoch 355/400
#  - 6s - loss: 3.4190 - val_loss: 87.2787
# Epoch 356/400
#  - 6s - loss: 4.3683 - val_loss: 86.0027
# Epoch 357/400
#  - 6s - loss: 3.7922 - val_loss: 80.2803
# Epoch 358/400
#  - 6s - loss: 4.5253 - val_loss: 79.5496
# Epoch 359/400
#  - 6s - loss: 5.0739 - val_loss: 85.3737
# Epoch 360/400
#  - 5s - loss: 5.8031 - val_loss: 84.2776
# Epoch 361/400
#  - 6s - loss: 7.6212 - val_loss: 89.3799
# Epoch 362/400
#  - 6s - loss: 7.5956 - val_loss: 93.4170
# Epoch 363/400
#  - 5s - loss: 7.2576 - val_loss: 86.2559
# Epoch 364/400
#  - 6s - loss: 6.9176 - val_loss: 86.1939
# Epoch 365/400
#  - 5s - loss: 6.5663 - val_loss: 97.8479
# Epoch 366/400
#  - 7s - loss: 4.8139 - val_loss: 88.8711
# Epoch 367/400
#  - 6s - loss: 3.6984 - val_loss: 93.5401
# Epoch 368/400
#  - 5s - loss: 3.3476 - val_loss: 89.8531
# Epoch 369/400
#  - 5s - loss: 3.4829 - val_loss: 89.0898
# Epoch 370/400
#  - 5s - loss: 2.0793 - val_loss: 89.9917
# Epoch 371/400
#  - 6s - loss: 1.7320 - val_loss: 88.3898
# Epoch 372/400
#  - 6s - loss: 1.3593 - val_loss: 89.5954
# Epoch 373/400
#  - 6s - loss: 1.3849 - val_loss: 87.5320
# Epoch 374/400
#  - 6s - loss: 1.1541 - val_loss: 87.9921
# Epoch 375/400
#  - 6s - loss: 1.0144 - val_loss: 87.1795
# Epoch 376/400
#  - 6s - loss: 1.0159 - val_loss: 88.8188
# Epoch 377/400
#  - 7s - loss: 1.2944 - val_loss: 86.1411
# Epoch 378/400
#  - 7s - loss: 1.1757 - val_loss: 87.9360
# Epoch 379/400
#  - 7s - loss: 1.1795 - val_loss: 87.0030
# Epoch 380/400
#  - 8s - loss: 1.3178 - val_loss: 87.0344
# Epoch 381/400
#  - 6s - loss: 1.6385 - val_loss: 85.7874
# Epoch 382/400
#  - 5s - loss: 1.2034 - val_loss: 86.6074
# Epoch 383/400
#  - 5s - loss: 1.3931 - val_loss: 85.6010
# Epoch 384/400
#  - 5s - loss: 1.6160 - val_loss: 86.1248
# Epoch 385/400
#  - 6s - loss: 2.1807 - val_loss: 90.7925
# Epoch 386/400
#  - 7s - loss: 2.1443 - val_loss: 84.7679
# Epoch 387/400
#  - 6s - loss: 2.0351 - val_loss: 85.4299
# Epoch 388/400
#  - 6s - loss: 2.5679 - val_loss: 87.4102
# Epoch 389/400

# %%
# make a prediction
yhat = model.predict(test_X)
yhat2 = model.predict(train_X)

# calculate RMSE
rmse = sqrt(mean_squared_error(yhat, test_y))
rmse2 = sqrt(mean_squared_error(yhat, test_y))
print('Test RMSE: %.3f' % rmse)

# %%
ypred = model.predict(train_X)
x = np.linspace(0,ypred.shape[0], ypred.shape[0]).reshape(ypred.shape[0],)
pyplot.plot(ypred[:,1],'r')
pyplot.plot(train_y[:,1],'b')
error=np.abs(ypred[:,[1]]-train_y[:,[1]])
pyplot.fill_between(x,(ypred[:,[1]]-error).reshape(ypred.shape[0],), (ypred[:,[1]]+error).reshape(ypred.shape[0],))
pyplot.show()
#ypred = model.predict(train_X)
x = np.linspace(0,ypred.shape[0], ypred.shape[0]).reshape(ypred.shape[0],)
pyplot.plot(ypred[:,0],'r')
pyplot.plot(train_y[:,0],'b')
error=np.abs(ypred[:,[0]]-train_y[:,[0]])
pyplot.fill_between(x,(ypred[:,[0]]-error).reshape(ypred.shape[0],), (ypred[:,[0]]+error).reshape(ypred.shape[0],))
pyplot.show()

# %%
x = np.linspace(0,yhat.shape[0], yhat.shape[0]).reshape(yhat.shape[0],)
pyplot.plot(yhat[:,[1]],'r')
pyplot.plot(test_y[:,[1]],'orange')
error=np.abs(yhat[:,[1]]-test_y[:,[1]])
pyplot.fill_between(x,(yhat[:,[1]]-error).reshape(yhat.shape[0],), (yhat[:,[1]]+error).reshape(yhat.shape[0],))
pyplot.show()
pyplot.plot(yhat[:,[0]],'r')
pyplot.plot(test_y[:,[0]],'orange')
error=np.abs(yhat[:,[0]]-test_y[:,[0]])
pyplot.fill_between(x,(yhat[:,[0]]-error).reshape(yhat.shape[0],), (yhat[:,[0]]+error).reshape(yhat.shape[0],))
pyplot.show()

# %%
pyplot.plot(yhat[:,[2]],'r')
pyplot.plot(test_y[:,[2]],'orange')
error=np.abs(yhat[:,[2]]-test_y[:,[2]])
pyplot.fill_between(x,(yhat[:,[2]]-error).reshape(yhat.shape[0],), (yhat[:,[2]]+error).reshape(yhat.shape[0],))
pyplot.show()

# %%
pyplot.plot(gt_sc)
pyplot.show()
