# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dense, Dropout
from keras import backend as K
import numpy as np
import seaborn as sns

# %%
sns.set()
sns.set_context('notebook',font_scale=1.4)
pyplot.rcParams['figure.figsize']=(25,12)

# %%
gt = read_csv('pca_df.csv')

# %%
list(gt)
# Out:
# ['PC1',
#  'PC2',
#  'PC3',
#  'PC4',
#  'PC5',
#  'PC6',
#  'PC7',
#  'PC8',
#  'PC9',
#  'PC10',
#  'PC11',
#  'PC12',
#  'PC13',
#  'PC14',
#  'PC15',
#  'PC16',
#  'PC17',
#  'PC18',
#  'PC19',
#  '.pose.pose.position.x',
#  '.pose.pose.position.y',
#  '.pose.pose.position.z',
#  '.pose.pose.orientation.x',
#  '.pose.pose.orientation.y',
#  '.pose.pose.orientation.z',
#  '.pose.pose.orientation.w']

# %%
print(gt.head())
gt = gt[[".pose.pose.position.x",".pose.pose.position.y"]]
gt = gt.values
print(gt)
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -0.851072  8.044216  0.326841 -1.044230  2.307484  1.075863  3.638323
# 1 -0.564265  8.143598  0.277990 -0.437284  1.891698  0.630888  3.733934
# 2 -0.344030  8.164862  0.485255 -0.638983  1.044315  1.209261  3.248368
# 3 -0.176959  8.179082  0.546207 -0.434098  0.953136  0.805202  3.497788
# 4 -0.109958  8.211974  0.486941 -0.138914  0.705735  0.631348  3.641314
#
#         PC8       PC9      PC10            ...                 PC17      PC18  \
# 0  4.274178  2.717133 -0.704123            ...            -1.655194  1.958867
# 1  1.592049  2.517208 -0.030412            ...             0.399774  1.910119
# 2  4.415842  0.998141  0.345600            ...             1.202330  1.503087
# 3  2.762791  1.320751  0.095173            ...             0.692561  2.706914
# 4  3.152261  0.852382  0.061224            ...             0.396012  2.190524
#
#        PC19  .pose.pose.position.x  .pose.pose.position.y  \
# 0  0.460268               0.909194              -0.086818
# 1 -0.349404               0.909462              -0.087017
# 2  0.549356               0.909194              -0.086818
# 3  0.255301               0.909194              -0.086818
# 4 -0.041790               0.909194              -0.086818
#
#    .pose.pose.position.z  .pose.pose.orientation.x  .pose.pose.orientation.y  \
# 0               0.819903                  0.010896                  0.010932
# 1               0.819894                  0.011137                  0.011660
# 2               0.819903                  0.010896                  0.010932
# 3               0.819903                  0.010896                  0.010932
# 4               0.819903                  0.010896                  0.010932
#
#    .pose.pose.orientation.z  .pose.pose.orientation.w
# 0                 -0.314718                  0.949060
# 1                 -0.314720                  0.949048
# 2                 -0.314718                  0.949060
# 3                 -0.314718                  0.949060
# 4                 -0.314718                  0.949060
#
# [5 rows x 26 columns]
# [[ 0.90919352 -0.08681773]
#  [ 0.90946156 -0.0870174 ]
#  [ 0.90919352 -0.08681773]
#  ...
#  [ 1.85841024 -0.5969516 ]
#  [ 1.85841024 -0.5969516 ]
#  [ 1.85841024 -0.5969516 ]]

# %%
ft = read_csv('pca_df.csv')
#print(ft)
ft = ft.values[:,0:19]
print(ft.shape)
print(gt.shape)
# Out:
# (18126, 19)
# (18126, 2)

# %%
#Pasar datos a variaciones de posición
print(len(ft))
print(len(gt))
print(gt)
gt_v=np.array([])
ft_v=ft[:ft.shape[0]-1,:]
for i in range(0,len(gt)-1):
    gt_v=np.append(gt_v,gt[i+1]*10-gt[i]*10).reshape((i+1,2))
    
plt.plot(gt_v)
print(gt_v)
# Out:
# 18126
# 18126
# [[ 0.90919352 -0.08681773]
#  [ 0.90946156 -0.0870174 ]
#  [ 0.90919352 -0.08681773]
#  ...
#  [ 1.85841024 -0.5969516 ]
#  [ 1.85841024 -0.5969516 ]
#  [ 1.85841024 -0.5969516 ]]
# [[ 0.00268042 -0.00199668]
#  [-0.00268042  0.00199668]
#  [ 0.          0.        ]
#  ...
#  [ 0.          0.        ]
#  [ 0.          0.        ]
#  [ 0.          0.        ]]

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# normalize features
ft_scaler = MinMaxScaler(feature_range=(-1, 1))
ft_sc = ft_scaler.fit_transform(ft_v)
#gt_scaler = MinMaxScaler(feature_range=(-1,1))
#gt_sc = gt_scaler.fit_transform(gt)
#specify the number of lag hours
gt_sc=gt_v
n_hours = 10
n_features = 19
# frame as supervised learning
reframed = series_to_supervised(ft_sc, n_hours, 1)
print(reframed.shape)
print(reframed.head())
# Out:
# (18115, 209)
#     var1(t-10)  var2(t-10)  var3(t-10)  var4(t-10)  var5(t-10)  var6(t-10)  \
# 10   -0.715661    0.912124   -0.516294   -0.909127   -0.554948    0.013421
# 11   -0.700331    0.923405   -0.518159   -0.886534   -0.576755   -0.040784
# 12   -0.688560    0.925818   -0.510249   -0.894042   -0.621199    0.029671
# 13   -0.679630    0.927432   -0.507923   -0.886416   -0.625981   -0.019550
# 14   -0.676049    0.931166   -0.510185   -0.875428   -0.638956   -0.040728
#
#     var7(t-10)  var8(t-10)  var9(t-10)  var10(t-10)    ...     var10(t)  \
# 10    0.655249    0.553081    0.373648    -0.045019    ...    -0.018136
# 11    0.673072    0.177793    0.345796    -0.021662    ...    -0.022740
# 12    0.582559    0.572903    0.134165    -0.008627    ...    -0.041608
# 13    0.629053    0.341605    0.179110    -0.017309    ...    -0.033457
# 14    0.655807    0.396101    0.113858    -0.018486    ...    -0.022294
#
#     var11(t)  var12(t)  var13(t)  var14(t)  var15(t)  var16(t)  var17(t)  \
# 10 -0.093213 -0.117487  0.032858 -0.114945  0.007821 -0.203628  0.229093
# 11 -0.206459 -0.176782 -0.106458 -0.156829 -0.040433 -0.054196  0.305606
# 12 -0.100022 -0.190172 -0.007054 -0.080169 -0.115595 -0.018248  0.114461
# 13 -0.158344 -0.177171  0.135092  0.028306  0.122936 -0.100145  0.129553
# 14 -0.275555 -0.214899  0.054090 -0.127503 -0.019077 -0.066916  0.276438
#
#     var18(t)  var19(t)
# 10 -0.030231 -0.253359
# 11  0.113269 -0.428118
# 12  0.114275 -0.429486
# 13  0.026465 -0.420714
# 14  0.090898 -0.354194
#
# [5 rows x 209 columns]

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 10000
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], gt_sc[:n_train_hours,:]
train_X_pos, train_y_pos = train[:, :n_obs], gt[:n_train_hours,:]
print(train_X)
print(train_y)
test_X, test_y = test[:, :n_obs], gt_sc[n_train_hours:,:]
test_X_pos, test_y_pos = test[:, :n_obs], gt[n_train_hours:,:]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
test_y = test_y[:-10,:]
# Out:
# [[-0.71566087  0.91212421 -0.51629433 ...  0.12552099 -0.07823277
#   -0.27253581]
#  [-0.7003313   0.92340481 -0.51815858 ...  0.22909346 -0.03023118
#   -0.25335908]
#  [-0.68855996  0.92581842 -0.51024888 ...  0.30560588  0.11326897
#   -0.42811761]
#  ...
#  [-0.7607772  -0.12804698 -0.51093121 ...  0.02868932  0.0877397
#   -0.48286006]
#  [-0.77243001 -0.12919634 -0.5096666  ... -0.15797009  0.08266238
#   -0.4530655 ]
#  [-0.77116535 -0.13449095 -0.50725277 ...  0.13853906  0.15366004
#   -0.44799775]]
# [[ 0.00268042 -0.00199668]
#  [-0.00268042  0.00199668]
#  [ 0.          0.        ]
#  ...
#  [-0.24424792  0.01335413]
#  [-0.09136438  0.01843363]
#  [-0.15974283  0.08608579]]
# (10000, 190) 10000 (10000, 2)
# (10000, 10, 19) (10000, 2) (8115, 10, 19) (8125, 2)

# %%
HUBER_DELTA = 0.5
def smoothL1(y_true, y_pred):
    x= K.abs(y_true - y_pred)
    x= K.switch(x < HUBER_DELTA, 0.5 * x ** 2, HUBER_DELTA * (x - 0.5 * HUBER_DELTA))
    return  K.sum(x)

# %%
def dice_loss():
    def dice(y_true, y_pred):
        return smoothL1(y_true, y_pred)
    return dice

# %%
# design network
model = Sequential()
#model.add(Dense(50))
#model.add(Dense(100))
#model.add(Dense(100))
#model.add(Dropout(0.5))
model.add(LSTM(50,input_shape=(train_X.shape[1],train_X.shape[2]),return_sequences=True,))
#model.add(Dropout(0.3))# return a single vector of dimension 32
model.add(LSTM(50,return_sequences=True,))  # returns a sequence of vectors of dimension 32
model.add(LSTM(50))  # returns a sequence of vectors of dimension 32

#model.add(Dense(100))
model.add(Dense(2))
model_dice = dice_loss()
# compile model
model.compile(loss='mse', optimizer='adam')
#model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=200, batch_size=150, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train on 10000 samples, validate on 8115 samples
# Epoch 1/200
#  - 17s - loss: 0.0239 - val_loss: 0.0263
# Epoch 2/200
#  - 7s - loss: 0.0235 - val_loss: 0.0262
# Epoch 3/200
#  - 7s - loss: 0.0232 - val_loss: 0.0264
# Epoch 4/200
#  - 9s - loss: 0.0232 - val_loss: 0.0267
# Epoch 5/200
#  - 8s - loss: 0.0231 - val_loss: 0.0270
# Epoch 6/200
#  - 7s - loss: 0.0230 - val_loss: 0.0277
# Epoch 7/200
#  - 7s - loss: 0.0229 - val_loss: 0.0281
# Epoch 8/200
#  - 7s - loss: 0.0229 - val_loss: 0.0282
# Epoch 9/200
#  - 7s - loss: 0.0228 - val_loss: 0.0279
# Epoch 10/200
#  - 10s - loss: 0.0228 - val_loss: 0.0281
# Epoch 11/200
#  - 9s - loss: 0.0227 - val_loss: 0.0286
# Epoch 12/200
#  - 9s - loss: 0.0226 - val_loss: 0.0290
# Epoch 13/200
#  - 9s - loss: 0.0226 - val_loss: 0.0294
# Epoch 14/200
#  - 9s - loss: 0.0225 - val_loss: 0.0297
# Epoch 15/200
#  - 9s - loss: 0.0225 - val_loss: 0.0301
# Epoch 16/200
#  - 9s - loss: 0.0224 - val_loss: 0.0305
# Epoch 17/200
#  - 9s - loss: 0.0223 - val_loss: 0.0308
# Epoch 18/200
#  - 9s - loss: 0.0222 - val_loss: 0.0312
# Epoch 19/200
#  - 9s - loss: 0.0222 - val_loss: 0.0315
# Epoch 20/200
#  - 9s - loss: 0.0222 - val_loss: 0.0320
# Epoch 21/200
#  - 9s - loss: 0.0221 - val_loss: 0.0327
# Epoch 22/200
#  - 9s - loss: 0.0220 - val_loss: 0.0334
# Epoch 23/200
#  - 9s - loss: 0.0220 - val_loss: 0.0340
# Epoch 24/200
#  - 9s - loss: 0.0220 - val_loss: 0.0344
# Epoch 25/200
#  - 9s - loss: 0.0218 - val_loss: 0.0348
# Epoch 26/200
#  - 9s - loss: 0.0217 - val_loss: 0.0349
# Epoch 27/200
#  - 9s - loss: 0.0217 - val_loss: 0.0347
# Epoch 28/200
#  - 8s - loss: 0.0216 - val_loss: 0.0355
# Epoch 29/200
#  - 9s - loss: 0.0215 - val_loss: 0.0366
# Epoch 30/200
#  - 9s - loss: 0.0214 - val_loss: 0.0378
# Epoch 31/200
#  - 9s - loss: 0.0213 - val_loss: 0.0389
# Epoch 32/200
#  - 9s - loss: 0.0211 - val_loss: 0.0428
# Epoch 33/200
#  - 9s - loss: 0.0211 - val_loss: 0.0450
# Epoch 34/200
#  - 9s - loss: 0.0210 - val_loss: 0.0486
# Epoch 35/200
#  - 9s - loss: 0.0208 - val_loss: 0.0477
# Epoch 36/200
#  - 9s - loss: 0.0208 - val_loss: 0.0520
# Epoch 37/200
#  - 8s - loss: 0.0208 - val_loss: 0.0517
# Epoch 38/200
#  - 8s - loss: 0.0208 - val_loss: 0.0658
# Epoch 39/200
#  - 7s - loss: 0.0209 - val_loss: 0.0619
# Epoch 40/200
#  - 8s - loss: 0.0208 - val_loss: 0.0678
# Epoch 41/200
#  - 7s - loss: 0.0205 - val_loss: 0.0445
# Epoch 42/200
#  - 7s - loss: 0.0205 - val_loss: 0.0512
# Epoch 43/200
#  - 8s - loss: 0.0203 - val_loss: 0.0782
# Epoch 44/200
#  - 9s - loss: 0.0203 - val_loss: 0.0499
# Epoch 45/200
#  - 9s - loss: 0.0201 - val_loss: 0.0602
# Epoch 46/200
#  - 8s - loss: 0.0201 - val_loss: 0.0560
# Epoch 47/200
#  - 7s - loss: 0.0197 - val_loss: 0.0713
# Epoch 48/200
#  - 7s - loss: 0.0195 - val_loss: 0.0769
# Epoch 49/200
#  - 7s - loss: 0.0194 - val_loss: 0.0592
# Epoch 50/200
#  - 8s - loss: 0.0200 - val_loss: 0.0752
# Epoch 51/200
#  - 9s - loss: 0.0199 - val_loss: 0.0769
# Epoch 52/200
#  - 10s - loss: 0.0193 - val_loss: 0.0657
# Epoch 53/200
#  - 11s - loss: 0.0198 - val_loss: 0.0648
# Epoch 54/200
#  - 8s - loss: 0.0198 - val_loss: 0.0822
# Epoch 55/200
#  - 8s - loss: 0.0193 - val_loss: 0.0631
# Epoch 56/200
#  - 8s - loss: 0.0190 - val_loss: 0.0664
# Epoch 57/200
#  - 8s - loss: 0.0192 - val_loss: 0.0579
# Epoch 58/200
#  - 7s - loss: 0.0188 - val_loss: 0.0715
# Epoch 59/200
#  - 8s - loss: 0.0185 - val_loss: 0.0590
# Epoch 60/200
#  - 9s - loss: 0.0184 - val_loss: 0.0768
# Epoch 61/200
#  - 8s - loss: 0.0179 - val_loss: 0.0994
# Epoch 62/200
#  - 8s - loss: 0.0178 - val_loss: 0.0646
# Epoch 63/200
#  - 8s - loss: 0.0181 - val_loss: 0.1103
# Epoch 64/200
#  - 8s - loss: 0.0177 - val_loss: 0.1130
# Epoch 65/200
#  - 7s - loss: 0.0178 - val_loss: 0.0728
# Epoch 66/200
#  - 7s - loss: 0.0175 - val_loss: 0.0933
# Epoch 67/200
#  - 8s - loss: 0.0177 - val_loss: 0.0953
# Epoch 68/200
#  - 8s - loss: 0.0170 - val_loss: 0.1124
# Epoch 69/200
#  - 7s - loss: 0.0170 - val_loss: 0.0656
# Epoch 70/200
#  - 9s - loss: 0.0164 - val_loss: 0.0803
# Epoch 71/200
#  - 8s - loss: 0.0171 - val_loss: 0.1009
# Epoch 72/200
#  - 9s - loss: 0.0164 - val_loss: 0.0691
# Epoch 73/200
#  - 8s - loss: 0.0163 - val_loss: 0.0633
# Epoch 74/200
#  - 8s - loss: 0.0167 - val_loss: 0.0681
# Epoch 75/200
#  - 9s - loss: 0.0161 - val_loss: 0.0933
# Epoch 76/200
#  - 7s - loss: 0.0163 - val_loss: 0.0490
# Epoch 77/200
#  - 8s - loss: 0.0160 - val_loss: 0.0673
# Epoch 78/200
#  - 7s - loss: 0.0155 - val_loss: 0.0531
# Epoch 79/200
#  - 8s - loss: 0.0153 - val_loss: 0.0549
# Epoch 80/200
#  - 8s - loss: 0.0153 - val_loss: 0.0603
# Epoch 81/200
#  - 8s - loss: 0.0151 - val_loss: 0.0469
# Epoch 82/200
#  - 7s - loss: 0.0152 - val_loss: 0.0632
# Epoch 83/200
#  - 7s - loss: 0.0147 - val_loss: 0.0496
# Epoch 84/200
#  - 7s - loss: 0.0144 - val_loss: 0.0633
# Epoch 85/200
#  - 8s - loss: 0.0145 - val_loss: 0.0788
# Epoch 86/200
#  - 8s - loss: 0.0150 - val_loss: 0.0592
# Epoch 87/200
#  - 7s - loss: 0.0146 - val_loss: 0.0539
# Epoch 88/200
#  - 8s - loss: 0.0143 - val_loss: 0.0435
# Epoch 89/200
#  - 10s - loss: 0.0138 - val_loss: 0.0665
# Epoch 90/200
#  - 9s - loss: 0.0140 - val_loss: 0.0450
# Epoch 91/200
#  - 8s - loss: 0.0138 - val_loss: 0.0578
# Epoch 92/200
#  - 7s - loss: 0.0139 - val_loss: 0.0523
# Epoch 93/200
#  - 8s - loss: 0.0137 - val_loss: 0.0575
# Epoch 94/200
#  - 7s - loss: 0.0129 - val_loss: 0.0404
# Epoch 95/200
#  - 7s - loss: 0.0133 - val_loss: 0.0513
# Epoch 96/200
#  - 8s - loss: 0.0132 - val_loss: 0.0506
# Epoch 97/200
#  - 9s - loss: 0.0132 - val_loss: 0.0479
# Epoch 98/200
#  - 8s - loss: 0.0125 - val_loss: 0.0408
# Epoch 99/200
#  - 7s - loss: 0.0131 - val_loss: 0.0450
# Epoch 100/200
#  - 8s - loss: 0.0132 - val_loss: 0.0436
# Epoch 101/200
#  - 9s - loss: 0.0131 - val_loss: 0.0411
# Epoch 102/200
#  - 8s - loss: 0.0125 - val_loss: 0.0481
# Epoch 103/200
#  - 12s - loss: 0.0133 - val_loss: 0.0472
# Epoch 104/200
#  - 11s - loss: 0.0121 - val_loss: 0.0415
# Epoch 105/200
#  - 10s - loss: 0.0124 - val_loss: 0.0447
# Epoch 106/200
#  - 8s - loss: 0.0125 - val_loss: 0.0427
# Epoch 107/200
#  - 8s - loss: 0.0114 - val_loss: 0.0445
# Epoch 108/200
#  - 9s - loss: 0.0112 - val_loss: 0.0390
# Epoch 109/200
#  - 8s - loss: 0.0113 - val_loss: 0.0526
# Epoch 110/200
#  - 8s - loss: 0.0117 - val_loss: 0.0408
# Epoch 111/200
#  - 7s - loss: 0.0115 - val_loss: 0.0459
# Epoch 112/200
#  - 9s - loss: 0.0117 - val_loss: 0.0400
# Epoch 113/200
#  - 10s - loss: 0.0106 - val_loss: 0.0405
# Epoch 114/200
#  - 10s - loss: 0.0103 - val_loss: 0.0498
# Epoch 115/200
#  - 8s - loss: 0.0102 - val_loss: 0.0407
# Epoch 116/200
#  - 7s - loss: 0.0107 - val_loss: 0.0382
# Epoch 117/200
#  - 7s - loss: 0.0105 - val_loss: 0.0469
# Epoch 118/200
#  - 7s - loss: 0.0107 - val_loss: 0.0418
# Epoch 119/200
#  - 8s - loss: 0.0107 - val_loss: 0.0429
# Epoch 120/200
#  - 9s - loss: 0.0105 - val_loss: 0.0408
# Epoch 121/200
#  - 10s - loss: 0.0105 - val_loss: 0.0421
# Epoch 122/200
#  - 8s - loss: 0.0102 - val_loss: 0.0434
# Epoch 123/200
#  - 8s - loss: 0.0098 - val_loss: 0.0400
# Epoch 124/200
#  - 7s - loss: 0.0096 - val_loss: 0.0486
# Epoch 125/200
#  - 7s - loss: 0.0105 - val_loss: 0.0397
# Epoch 126/200
#  - 8s - loss: 0.0097 - val_loss: 0.0411
# Epoch 127/200
#  - 8s - loss: 0.0094 - val_loss: 0.0377
# Epoch 128/200
#  - 9s - loss: 0.0096 - val_loss: 0.0420
# Epoch 129/200
#  - 9s - loss: 0.0103 - val_loss: 0.0429
# Epoch 130/200
#  - 9s - loss: 0.0104 - val_loss: 0.0398
# Epoch 131/200
#  - 9s - loss: 0.0099 - val_loss: 0.0394
# Epoch 132/200
#  - 9s - loss: 0.0095 - val_loss: 0.0518
# Epoch 133/200
#  - 9s - loss: 0.0102 - val_loss: 0.0409
# Epoch 134/200
#  - 9s - loss: 0.0106 - val_loss: 0.0414
# Epoch 135/200
#  - 8s - loss: 0.0093 - val_loss: 0.0461
# Epoch 136/200
#  - 8s - loss: 0.0088 - val_loss: 0.0419
# Epoch 137/200
#  - 7s - loss: 0.0087 - val_loss: 0.0392
# Epoch 138/200
#  - 7s - loss: 0.0090 - val_loss: 0.0417
# Epoch 139/200
#  - 8s - loss: 0.0097 - val_loss: 0.0359
# Epoch 140/200
#  - 9s - loss: 0.0095 - val_loss: 0.0453
# Epoch 141/200
#  - 9s - loss: 0.0092 - val_loss: 0.0395
# Epoch 142/200
#  - 8s - loss: 0.0096 - val_loss: 0.0415
# Epoch 143/200
#  - 8s - loss: 0.0095 - val_loss: 0.0378
# Epoch 144/200
#  - 7s - loss: 0.0100 - val_loss: 0.0429
# Epoch 145/200
#  - 10s - loss: 0.0093 - val_loss: 0.0396
# Epoch 146/200
#  - 9s - loss: 0.0088 - val_loss: 0.0423
# Epoch 147/200
#  - 9s - loss: 0.0090 - val_loss: 0.0392
# Epoch 148/200
#  - 9s - loss: 0.0086 - val_loss: 0.0375
# Epoch 149/200
#  - 9s - loss: 0.0087 - val_loss: 0.0366
# Epoch 150/200
#  - 9s - loss: 0.0080 - val_loss: 0.0380
# Epoch 151/200
#  - 9s - loss: 0.0078 - val_loss: 0.0387
# Epoch 152/200
#  - 9s - loss: 0.0076 - val_loss: 0.0383
# Epoch 153/200
#  - 9s - loss: 0.0079 - val_loss: 0.0361
# Epoch 154/200
#  - 9s - loss: 0.0083 - val_loss: 0.0379
# Epoch 155/200
#  - 9s - loss: 0.0085 - val_loss: 0.0359
# Epoch 156/200
#  - 9s - loss: 0.0084 - val_loss: 0.0366
# Epoch 157/200
#  - 10s - loss: 0.0084 - val_loss: 0.0369
# Epoch 158/200
#  - 9s - loss: 0.0089 - val_loss: 0.0378
# Epoch 159/200
#  - 9s - loss: 0.0085 - val_loss: 0.0371
# Epoch 160/200
#  - 9s - loss: 0.0085 - val_loss: 0.0368
# Epoch 161/200
#  - 8s - loss: 0.0090 - val_loss: 0.0359
# Epoch 162/200
#  - 8s - loss: 0.0081 - val_loss: 0.0377
# Epoch 163/200
#  - 7s - loss: 0.0077 - val_loss: 0.0355
# Epoch 164/200
#  - 8s - loss: 0.0077 - val_loss: 0.0431
# Epoch 165/200
#  - 7s - loss: 0.0075 - val_loss: 0.0374
# Epoch 166/200
#  - 9s - loss: 0.0077 - val_loss: 0.0372
# Epoch 167/200
#  - 8s - loss: 0.0073 - val_loss: 0.0369
# Epoch 168/200
#  - 8s - loss: 0.0073 - val_loss: 0.0369
# Epoch 169/200
#  - 9s - loss: 0.0072 - val_loss: 0.0390
# Epoch 170/200
#  - 8s - loss: 0.0076 - val_loss: 0.0359
# Epoch 171/200
#  - 7s - loss: 0.0076 - val_loss: 0.0371
# Epoch 172/200
#  - 9s - loss: 0.0077 - val_loss: 0.0404
# Epoch 173/200
#  - 7s - loss: 0.0073 - val_loss: 0.0370
# Epoch 174/200
#  - 8s - loss: 0.0069 - val_loss: 0.0391
# Epoch 175/200
#  - 7s - loss: 0.0066 - val_loss: 0.0374
# Epoch 176/200
#  - 7s - loss: 0.0066 - val_loss: 0.0375
# Epoch 177/200
#  - 7s - loss: 0.0070 - val_loss: 0.0379
# Epoch 178/200
#  - 7s - loss: 0.0074 - val_loss: 0.0366
# Epoch 179/200
#  - 8s - loss: 0.0080 - val_loss: 0.0396
# Epoch 180/200
#  - 7s - loss: 0.0082 - val_loss: 0.0387
# Epoch 181/200
#  - 7s - loss: 0.0088 - val_loss: 0.0379
# Epoch 182/200
#  - 7s - loss: 0.0081 - val_loss: 0.0389
# Epoch 183/200
#  - 8s - loss: 0.0082 - val_loss: 0.0373
# Epoch 184/200
#  - 9s - loss: 0.0080 - val_loss: 0.0360
# Epoch 185/200
#  - 10s - loss: 0.0080 - val_loss: 0.0382
# Epoch 186/200
#  - 8s - loss: 0.0073 - val_loss: 0.0410
# Epoch 187/200
#  - 8s - loss: 0.0070 - val_loss: 0.0372
# Epoch 188/200
#  - 7s - loss: 0.0072 - val_loss: 0.0365
# Epoch 189/200
#  - 8s - loss: 0.0069 - val_loss: 0.0352
# Epoch 190/200
#  - 8s - loss: 0.0067 - val_loss: 0.0359
# Epoch 191/200
#  - 8s - loss: 0.0069 - val_loss: 0.0389
# Epoch 192/200
#  - 9s - loss: 0.0065 - val_loss: 0.0363
# Epoch 193/200
#  - 8s - loss: 0.0065 - val_loss: 0.0359
# Epoch 194/200
#  - 7s - loss: 0.0069 - val_loss: 0.0376
# Epoch 195/200
#  - 7s - loss: 0.0067 - val_loss: 0.0371
# Epoch 196/200
#  - 7s - loss: 0.0065 - val_loss: 0.0369
# Epoch 197/200
#  - 7s - loss: 0.0065 - val_loss: 0.0373
# Epoch 198/200
#  - 8s - loss: 0.0067 - val_loss: 0.0356
# Epoch 199/200
#  - 7s - loss: 0.0068 - val_loss: 0.0381
# Epoch 200/200
#  - 7s - loss: 0.0071 - val_loss: 0.0371

# %%
# make a prediction
yhat = model.predict(test_X)
yhat2 = model.predict(train_X)

print(type(yhat))
print(type(test_y))

# calculate RMSE
rmse = sqrt(mean_squared_error(yhat, test_y))
rmse2 = sqrt(mean_squared_error(yhat, test_y))
print('Test RMSE: %.3f' % rmse)

rmse = mean_squared_error(yhat, test_y)
print('Test RMSE: %.3f' % rmse)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Test RMSE: 0.193
# Test RMSE: 0.037

# %%
ypred = model.predict(train_X)
x = np.linspace(0,ypred.shape[0], ypred.shape[0]).reshape(ypred.shape[0],)
pyplot.plot(ypred[:,1],'r')
pyplot.plot(train_y[:,1],'b')
error=np.abs(ypred[:,[1]]-train_y[:,[1]])
pyplot.fill_between(x,(ypred[:,[1]]-error).reshape(ypred.shape[0],), (ypred[:,[1]]+error).reshape(ypred.shape[0],))
pyplot.legend(['predicted','true'])
pyplot.show()
#ypred = model.predict(train_X)
x = np.linspace(0,ypred.shape[0], ypred.shape[0]).reshape(ypred.shape[0],)
pyplot.plot(ypred[:,0],'r')
pyplot.plot(train_y[:,0],'b')
error=np.abs(ypred[:,[0]]-train_y[:,[0]])
pyplot.fill_between(x,(ypred[:,[0]]-error).reshape(ypred.shape[0],), (ypred[:,[0]]+error).reshape(ypred.shape[0],))
pyplot.legend(['predicted','true'])
pyplot.show()

# %%
train_pred_x=np.zeros(ypred.shape[0])
ypred2=ypred/10
for i in range(ypred.shape[0]):
    if i%50==0:
        train_pred_x[i]=train_y_pos[i,[1]]
    else:
        train_pred_x[i]=ypred2[i,[1]]+train_pred_x[i-1]
#train_pred_x= np.cumsum(ypred[:,[1]], dtype=float)+train_y_pos[0,[1]]
pyplot.plot(train_pred_x)
pyplot.plot(train_y_pos[:,[1]],'orange')

# %%
ypred_2=ypred[:,:]/10
train_pred_x=np.zeros(ypred.shape[0])
for i in range(ypred.shape[0]):
    if i%10000==0:
        train_pred_x[i]=train_y_pos[i,[1]]
    else:
        train_pred_x[i]=ypred_2[i,[1]]+train_pred_x[i-1]
#train_pred_x= np.cumsum(ypred[:,[1]], dtype=float)+train_y_pos[0,[1]]
pyplot.plot(train_pred_x)
pyplot.plot(train_y_pos[:,[1]],'orange')

# %%
x = np.linspace(0,yhat.shape[0], yhat.shape[0]).reshape(yhat.shape[0],)
pyplot.plot(yhat[:,[1]],'r')
pyplot.plot(test_y[:,[1]],'orange')
error=np.abs(yhat[:,[1]]-test_y[:,[1]])
pyplot.fill_between(x,(yhat[:,[1]]-error).reshape(yhat.shape[0],), (yhat[:,[1]]+error).reshape(yhat.shape[0],))
pyplot.legend(['predicted','true'])
pyplot.show()
pyplot.plot(yhat[:,[0]],'r')
pyplot.plot(test_y[:,[0]],'orange')
error=np.abs(yhat[:,[0]]-test_y[:,[0]])
pyplot.fill_between(x,(yhat[:,[0]]-error).reshape(yhat.shape[0],), (yhat[:,[0]]+error).reshape(yhat.shape[0],))
pyplot.legend(['predicted','true'])
pyplot.show()

# %%
pyplot.plot(yhat[:,[2]],'r')
pyplot.plot(test_y[:,[2]],'orange')
error=np.abs(yhat[:,[2]]-test_y[:,[2]])
pyplot.fill_between(x,(yhat[:,[2]]-error).reshape(yhat.shape[0],), (yhat[:,[2]]+error).reshape(yhat.shape[0],))
pyplot.show()

# %%
pyplot.plot(gt_sc)
pyplot.show()

# %%
ypred_2=yhat[:,:]/10
train_pred_y=np.zeros(yhat.shape[0])
for i in range(yhat.shape[0]):
    if i%100000==0:
        train_pred_y[i]=test_y_pos[i,[0]]
    else:
        train_pred_y[i]=ypred_2[i,[0]]+train_pred_y[i-1]
#train_pred_x= np.cumsum(ypred[:,[1]], dtype=float)+train_y_pos[0,[1]]
pyplot.plot(train_pred_y, label='Pred Test')
pyplot.plot(train_y_pos[:,[0]],'orange', label='Test GT')
pyplot.legend(loc=1, borderaxespad=0., fontsize=20)
pyplot.title("Training Eje X")
plt.show()

ypred_2=yhat[:,:]/10
train_pred_x=np.zeros(yhat.shape[0])
for i in range(yhat.shape[0]):
    if i%100000==0:
        train_pred_x[i]=test_y_pos[i,[1]]
    else:
        train_pred_x[i]=ypred_2[i,[1]]+train_pred_x[i-1]
#train_pred_x= np.cumsum(ypred[:,[1]], dtype=float)+train_y_pos[0,[1]]
pyplot.plot(train_pred_x, label='Pred Test')
pyplot.plot(train_y_pos[:,[1]],'orange', label='Test GT')
pyplot.legend(loc=1, borderaxespad=0., fontsize=20)
pyplot.title("Training Eje Y")
# Out:
# Text(0.5,1,'Training Eje Y')

# %%
ypred_2=yhat[:,:]/10
train_pred_y=np.zeros(yhat.shape[0])
for i in range(yhat.shape[0]):
    if i%100000==0:
        train_pred_y[i]=test_y_pos[i,[0]]
    else:
        train_pred_y[i]=ypred_2[i,[0]]+train_pred_y[i-1]
#train_pred_x= np.cumsum(ypred[:,[1]], dtype=float)+train_y_pos[0,[1]]
pyplot.plot(train_pred_y, label='Pred Test')
pyplot.plot(test_y_pos[:,[0]],'orange', label='Test GT')
pyplot.legend(loc=1, borderaxespad=0., fontsize=20)
pyplot.title("Testing Eje X")
plt.show()

ypred_2=yhat[:,:]/10
train_pred_x=np.zeros(yhat.shape[0])
for i in range(yhat.shape[0]):
    if i%100000==0:
        train_pred_x[i]=test_y_pos[i,[1]]
    else:
        train_pred_x[i]=ypred_2[i,[1]]+train_pred_x[i-1]
#train_pred_x= np.cumsum(ypred[:,[1]], dtype=float)+train_y_pos[0,[1]]
pyplot.plot(train_pred_x, label='Pred Test')
pyplot.plot(test_y_pos[:,[1]],'orange', label='Test GT')
pyplot.legend(loc=1, borderaxespad=0., fontsize=20)
pyplot.title("Testing Eje Y")
# Out:
# Text(0.5,1,'Testing Eje Y')
